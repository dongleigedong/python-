# %%
import matplotlib.pyplot as plt
import numpy as np
a=[1,2,3,4,5]
# plt.plot(a)

b=[6,7,8,9,4]
# plt.plot(b,a)
# plt.plot(a,b,'--')
# plt.plot(a,b,'y--')
# plt.plot(a,b,'b*')
# plt.show()

# c=[10,20,30]
# d=[2,4,8]

a=np.arange(0.0,2.0,0.1)
b=np.sin(a*np.pi)
# plt.plot(a,b,'r--')
c=np.arange(0.0,4,0.1)
d=np.sin(c*np.pi*0.5)
plt.plot(a,b,'r--',c,d,'b--')
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('this is a demo')
# plt.legend([b,d],['this is x','this is y'],loc='this is demo')
plt.show()

# %%
x=np.arange(10)
y=np.sin(x)
plt.plot(x,y,linestyle='--',color='orange',linewidth=1,marker='*')
plt.grid(True)
plt.title("aa")
plt.xlabel('x')
plt.ylabel('y')
plt.legend(['X'])#图例
plt.show()

# %%
x=np.arange(10)
y1=15+5*x
y2=x*x
plt.plot(x,y2,linestyle='--',color='blue',linewidth=1,marker='p')
plt.plot(x,y1,linestyle='-',color='red',linewidth=1)
plt.legend(['y1 data','y2 data'])#图例
plt.title("plot 1")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0,0.5,'y-axis')

# %%
x=np.arange(-1,2,0.25)
y1=x**2
y2=2*x+1
plt.plot(x,y1,'r--',x,y2,'b')
plt.yticks([-2,-1,1,2],['bad','really bad','good','really good'])
# 获取当前的坐标轴, gca = get current axis
ax = plt.gca()
# 设置右边框和上边框
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
# 设置x轴, y周在(0, 0)的位置
ax.spines['bottom'].set_position(('data', 0))
ax.spines['left'].set_position(('data', 0))
plt.show()

# %%
from matplotlib.ticker import MultipleLocator,FormatStrFormatter
#自定义x轴刻度
x=np.arange(30)
y=np.sin(x)
plt.figure(figsize=(12,6))
plt.plot(x,y)
#设置x轴的刻度间隔
g=plt.gca()
g.xaxis.set_major_locator(MultipleLocator(4))
#设置X轴的刻度显示格式
g.xaxis.set_major_formatter(FormatStrFormatter("%d-RMB"))
plt.gcf().autofmt_xdate()

plt.show()

# %%
from matplotlib.ticker import MultipleLocator,FormatStrFormatter
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
from datetime import datetime
t2=pd.date_range('2018-01-01','2018-08-03',30)
t2

# x=np.arange(30)
# Out:
# DatetimeIndex([          '2018-01-01 00:00:00',
#                '2018-01-08 09:06:12.413793024',
#                '2018-01-15 18:12:24.827586304',
#                '2018-01-23 03:18:37.241379328',
#                '2018-01-30 12:24:49.655172352',
#                '2018-02-06 21:31:02.068965632',
#                '2018-02-14 06:37:14.482758656',
#                '2018-02-21 15:43:26.896551680',
#                '2018-03-01 00:49:39.310344704',
#                '2018-03-08 09:55:51.724137984',
#                '2018-03-15 19:02:04.137931008',
#                '2018-03-23 04:08:16.551724032',
#                '2018-03-30 13:14:28.965517312',
#                '2018-04-06 22:20:41.379310336',
#                '2018-04-14 07:26:53.793103360',
#                '2018-04-21 16:33:06.206896640',
#                '2018-04-29 01:39:18.620689664',
#                '2018-05-06 10:45:31.034482688',
#                '2018-05-13 19:51:43.448275968',
#                '2018-05-21 04:57:55.862068992',
# ...

# %%
import datetime
from matplotlib.ticker import MultipleLocator,FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np
import time
now = datetime.datetime.now()
time=[]
day1=[]
# datetime.datetime(2017, 6, 25, 20, 53, 40, 36492)
for i in range(0,30,1):
    day =  datetime.timedelta(days=i)
    time1=now + day
    time.append(str(time1.date()))
    day1.append(time1.day)
# time
# day1
# y=np.arange(30)
plt.figure(figsize=(15,10))
plt.plot(time,day1)
plt.gcf().autofmt_xdate()
plt.show()
# datetime.datetime(2017, 6, 28, 20, 53, 40, 36492)

# %%
# x=[datetime.date.today()+datetime.timedelta(i) for i in range(30)]
# print(x)
# y=np.sin(np.arange(30))
# plt.figure(figsize=(12,6))
# plt.plot(x,y)
# g=plt.gca()
# g.xaxis.set_major
